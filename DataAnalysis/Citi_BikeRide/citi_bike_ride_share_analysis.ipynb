# %% [markdown]
# # Import packages we need
#
# Download file from:
# [citi bike data] (https://www.kaggle.com/datasets/hassanabsar/nyc-citi-bike-ride-share-system-data-2023)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Basic data check
#
# We need to perform some basic data check, set up the index, drop column that we have no informations about etc..

# %%
csv_path = '../files/sample_citibike_2023.csv'
df_citibike = pd.read_csv(csv_path, dtype={'start_station_id': str}) # fix inconsitent type
df_citibike.head()
# Out:
#    Unnamed: 0           ride_id rideable_type           started_at  \
# 0    12536574  6A1558E5EB8E9B3B  classic_bike  2023-06-25 06:44:47
# 1    20766033  F5DAABF8EAD39B32  classic_bike  2023-08-15 18:05:37
# 2    17246346  CC4D3C1C193EBCDD  classic_bike  2023-07-05 15:00:28
# 3     3860641  541D7A53817AF238  classic_bike  2023-03-05 11:29:02
# 4    27285265  EACA2B802BFED979  classic_bike  2023-10-17 15:02:23
#
#               ended_at                 start_station_name start_station_id  \
# 0  2023-06-25 07:02:43              Walton Ave & E 168 St          8179.03
# 1  2023-08-15 18:12:06  Grand Army Plaza & Central Park S          6839.10
# 2  2023-07-05 15:06:34      Knickerbocker Ave & Thames St          5018.06
# 3  2023-03-05 11:36:36        DeKalb Ave & Vanderbilt Ave          4461.04
# 4  2023-10-17 15:06:40              Liberty St & Broadway          5105.01
#
#            end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0             Icahn Stadium        7514.01  40.836655 -73.918324  40.793460
# 1           2 Ave & E 72 St        6925.09  40.764004 -73.973974  40.768762
# 2     Melrose St & Broadway        4801.04  40.705446 -73.929975  40.697481
# 3  Pacific St & Classon Ave        4148.07  40.689425 -73.968898  40.679194
# 4            West Thames St        5114.06  40.708164 -74.010369  40.708347
#
#      end_lng member_casual
# 0 -73.923890        member
# 1 -73.958408        member
# 2 -73.935877        casual
# 3 -73.958790        member
# 4 -74.017134        member

# %%
df_citibike = df_citibike.drop('Unnamed: 0', axis='columns') # there is no information in documentation about this column, drop it
df_citibike = df_citibike.set_index('ride_id') # ride_id identifies each ride/observation
df_citibike.head()
# Out:
#                  rideable_type           started_at             ended_at  \
# ride_id
# 6A1558E5EB8E9B3B  classic_bike  2023-06-25 06:44:47  2023-06-25 07:02:43
# F5DAABF8EAD39B32  classic_bike  2023-08-15 18:05:37  2023-08-15 18:12:06
# CC4D3C1C193EBCDD  classic_bike  2023-07-05 15:00:28  2023-07-05 15:06:34
# 541D7A53817AF238  classic_bike  2023-03-05 11:29:02  2023-03-05 11:36:36
# EACA2B802BFED979  classic_bike  2023-10-17 15:02:23  2023-10-17 15:06:40
#
#                                  start_station_name start_station_id  \
# ride_id
# 6A1558E5EB8E9B3B              Walton Ave & E 168 St          8179.03
# F5DAABF8EAD39B32  Grand Army Plaza & Central Park S          6839.10
# CC4D3C1C193EBCDD      Knickerbocker Ave & Thames St          5018.06
# 541D7A53817AF238        DeKalb Ave & Vanderbilt Ave          4461.04
# EACA2B802BFED979              Liberty St & Broadway          5105.01
#
#                           end_station_name end_station_id  start_lat  \
# ride_id
# 6A1558E5EB8E9B3B             Icahn Stadium        7514.01  40.836655
# F5DAABF8EAD39B32           2 Ave & E 72 St        6925.09  40.764004
# CC4D3C1C193EBCDD     Melrose St & Broadway        4801.04  40.705446
# 541D7A53817AF238  Pacific St & Classon Ave        4148.07  40.689425
# EACA2B802BFED979            West Thames St        5114.06  40.708164
#
#                   start_lng    end_lat    end_lng member_casual
# ride_id
# 6A1558E5EB8E9B3B -73.918324  40.793460 -73.923890        member
# F5DAABF8EAD39B32 -73.973974  40.768762 -73.958408        member
# CC4D3C1C193EBCDD -73.929975  40.697481 -73.935877        casual
# 541D7A53817AF238 -73.968898  40.679194 -73.958790        member
# EACA2B802BFED979 -74.010369  40.708347 -74.017134        member
